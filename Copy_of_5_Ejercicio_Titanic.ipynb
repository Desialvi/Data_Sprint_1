# %% [markdown]
# <a href="https://colab.research.google.com/github/Desialvi/Data_Sprint_1/blob/main/Copy_of_5_Ejercicio_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EJERCICIO TITANIC
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/RMS_Titanic_3.jpg/800px-RMS_Titanic_3.jpg)
#
# Para el ejercicio final, intentá combinar todas las habilidades que aprendiste hasta ahora para cumplir las consignas. **Sentite libre de desviarte de las consignas y explorar los datos que te parezcan interesantes.**
#
# **Link dataset**: https://raw.githubusercontent.com/riverofacundo/cursos/main/rain.csv
#
# Este archivo contiene información sobre todos los pasajeros y tripulantes del RMS Titanic. Sus columnas son:
#
# - ``name``: strings with the name of the passenger.
# - ``gender``: "male" or "female".
# - ``age``: a float with the persons age on the day of the sinking. The age of babies (under 12 months) is given as a fraction of one year.
# - ``class``: a string specifying the class (1st, 2nd or 3rd) for passengers or the type of service aboard for crew members.
# - ``embarked``: the persons place of of embarkment.
# - ``country``: the persons home country.
# - ``ticketno``: the persons ticket number (NA for crew members).
# - ``fare``: the ticket price (NA for crew members, musicians and employees of the shipyard company).
# - ``sibsp``: a number specifying the number if siblings/spouses aboard.
# - ``parch``: a number specifying the number of parents/children aboard.
# - ``survived``: a string ("no" or "yes") specifying whether the person has survived the sinking.

# %%
import pandas as pd
titanic = pd.read_csv(r'/content/train.csv')
titanic.dropna(axis = 0, inplace = True)

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
titanic['Embarked'].unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Leer el dataset y mostrar:
#
# - Los primeros 5 registros
# - Los ultimos 5 registros

# %%
titanic.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                          Carlsson, Mr. Frans Olof    male  33.0      0
# 879     Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                      Graham, Miss. Margaret Edith  female  19.0      0
# 889                             Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch  Ticket     Fare        Cabin Embarked
# 871      1   11751  52.5542          D35        S
# 872      0     695   5.0000  B51 B53 B55        S
# 879      1   11767  83.1583          C50        C
# 887      0  112053  30.0000          B42        S
# 889      0  111369  30.0000         C148        C

# %% [markdown]
# ¿Cuantas filas y columnas tiene el dataset?

# %%
print(f"Este dataframe tiene {titanic.shape[0]} filas y {titanic.shape[1]} columnas")
# Out:
# Este dataframe tiene 183 filas y 12 columnas

# %% [markdown]
# Cambiar el nombre de la columna ``age`` por ``edad``

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#opcion1 titanic.columns = ['name', 'gender', 'edad', 'class', 'embarked', 'country', 'ticketno',
#'fare', 'sibsp', 'parch', 'survived']

#opcion 2

titanic.rename(columns = {'Age':'edad'}, inplace = True)

titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex  edad  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %% [markdown]
# Aplicar un ``describe`` y sacar por lo menos 3 conclusiones

# %%
titanic.describe()
# Habían 3 clases en el Titanic,
# Viajaron hasta 4 hijos por padre
# La edad promedio era de 35 años, máximo de 80
# Out:
#        PassengerId    Survived      Pclass        edad       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.674426    0.464481
# std     247.052476    0.470725    0.515187   15.643866    0.644159
# min       2.000000    0.000000    1.000000    0.920000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %% [markdown]
# ¿Cuales son las personas que tienen los tickets con mayores precio?

# %%
titanic.groupby('Pclass')['Fare'].mean()

#Los pasaejeros de la clase 1 pagaron más
# Out:
# Pclass
# 1    88.683228
# 2    18.444447
# 3    11.027500
# Name: Fare, dtype: float64

# %%
titanic.groupby('Sex')['Fare'].mean()
#Las mujeres en promedio pagaron más caro
# Out:
# Sex
# female    89.000900
# male      69.124343
# Name: Fare, dtype: float64

# %% [markdown]
# Contar la cantidad de personas por genero

# %%
titanic.groupby('Sex').count()
#88 mujeres y 95 hombres
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female           88        88      88    88   88     88     88      88    88
# male             95        95      95    95   95     95     95      95    95
#
#         Cabin  Embarked
# Sex
# female     88        88
# male       95        95

# %% [markdown]
# Encontrar la edad promedio de todas las personas a bordo

# %%
edad_promedio = titanic['edad'].mean()
print("La edad promedio era", edad_promedio)
# Out:
# La edad promedio era 35.6744262295082

# %% [markdown]
# Filtrar solo los hombres, de primera clase, que sean de Estados unidos o Inglaterra. Finalmente ordenarlos por el precio del ticket

# %%
df_filtrada = titanic.loc[(titanic['Sex']== 'male')
                          & (titanic['Pclass'] ==1)]


df_filtrada.sort_values('Fare').head(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 263          264         0       1
# 806          807         0       1
# 872          873         0       1
# 662          663         0       1
# 707          708         1       1
# 701          702         1       1
# 512          513         1       1
# 572          573         1       1
# 252          253         0       1
# 430          431         1       1
# 456          457         0       1
# 857          858         1       1
# 460          461         1       1
# 536          537         0       1
# 452          453         0       1
# 331          332         0       1
# 487          488         0       1
# 273          274         0       1
# 889          890         1       1
# 630          631         1       1
# 782          783         0       1
# 449          450         1       1
# 492          493         0       1
# 632          633         1       1
# 174          175         0       1
# 209          210         1       1
# 625          626         0       1
# 170          171         0       1
# 515          516         0       1
# 96            97         0       1
# 647          648         1       1
# 339          340         0       1
# 23            24         1       1
# 462          463         0       1
# 583          584         0       1
# 867          868         0       1
# 6              7         0       1
# 712          713         1       1
# 671          672         0       1
# 110          111         0       1
# 621          622         1       1
# 248          249         1       1
# 748          749         0       1
# 724          725         1       1
# 137          138         0       1
# 370          371         1       1
# 434          435         0       1
# 599          600         1       1
# 690          691         1       1
# 92            93         0       1
#
#                                              Name   Sex  edad  SibSp  Parch  \
# 263                         Harrison, Mr. William  male  40.0      0      0
# 806                        Andrews, Mr. Thomas Jr  male  39.0      0      0
# 872                      Carlsson, Mr. Frans Olof  male  33.0      0      0
# 662                    Colley, Mr. Edward Pomeroy  male  47.0      0      0
# 707             Calderhead, Mr. Edward Pennington  male  42.0      0      0
# 701              Silverthorne, Mr. Spencer Victor  male  35.0      0      0
# 512                     McGough, Mr. James Robert  male  36.0      0      0
# 572              Flynn, Mr. John Irwin ("Irving")  male  36.0      0      0
# 252                     Stead, Mr. William Thomas  male  62.0      0      0
# 430     Bjornstrom-Steffansson, Mr. Mauritz Hakan  male  28.0      0      0
# 456                     Millet, Mr. Francis Davis  male  65.0      0      0
# 857                        Daly, Mr. Peter Denis   male  51.0      0      0
# 460                           Anderson, Mr. Harry  male  48.0      0      0
# 96      PC 17754  34.6542           A5        C
# 647        13213  35.5000          A26        C
# 339       113784  35.5000            T        S
# 23        113788  35.5000           A6        S
# 462       111320  38.5000          E63        S
# 583        13049  40.1250          A10        C
# 867     PC 17590  50.4958          A24        S
# 6          17463  51.8625          E46        S
# 712        19996  52.0000         C126        S
# 671   F.C. 12750  52.0000          B71        S
# 110       110465  52.0000         C110        S
# 621        11753  52.5542          D19        S
# 248        11751  52.5542          D35        S
# 748       113773  53.1000          D30        S
# 724       113806  53.1000           E8        S
# 137       113803  53.1000         C123        S
# 370        11765  55.4417          E50        C
# 434        13507  55.9000          E44        S
# 599     PC 17485  56.9292          A20        C
# 690        17474  57.0000          B20        S
# 92   W.E.P. 5734  61.1750          E31        S

# %% [markdown]
# Encontrar la edad promedio de los hombres a bordo

# %%
edad_hombres = titanic.loc[(titanic['Sex']== 'male'), 'edad'].mean()
print(f"La edad promedio de los hombres a bordo era de {edad_hombres}")
# Out:
# La edad promedio de los hombres a bordo era de 38.45178947368421

# %% [markdown]
# Seleccionar solo las personas que pertenezca a la clase '3rd', luego contar cuantos sobrevivieron y cuantos murieron.

# %%
supervivientes_3rd = titanic.loc[(titanic['Pclass']== 3) &
            (titanic['Survived'] == 1),'Survived'].count()
fallecidos_3rd = titanic.loc[(titanic['Pclass']== 3) &
            (titanic['Survived'] == 0),'Survived'].count()
print(f"En el Titanic murieron {fallecidos_3rd} personas y sobrevivieron {supervivientes_3rd} personas con boletos de tercera clase según este DataSet" )
# Out:
# En el Titanic murieron 5 personas y sobrevivieron 5 personas con boletos de tercera clase según este DataSet

# %% [markdown]
# Tarifa promedio correspondiente a cada tipo de clase

# %%
titanic.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    88.683228
# 2    18.444447
# 3    11.027500
# Name: Fare, dtype: float64

# %% [markdown]
# Encuentre la tasa de supervivencia promedio correspondiente a cada tipo de cabina

# %%
titanic_sob_1st = titanic.loc[(titanic['Survived'] == 1) & (titanic['Pclass'] == 1),'Pclass'].count()
titanic_total_1st = titanic.loc[(titanic['Pclass'] == 1), 'Pclass'].count()
titanic_sob_2nd = titanic.loc[(titanic['Survived'] == 1) & (titanic['Pclass'] == 2),'Pclass'].count()
titanic_total_2nd = titanic.loc[(titanic['Pclass'] == 2), 'Pclass'].count()
titanic_sob_3rd = titanic.loc[(titanic['Survived'] == 1) & (titanic['Pclass'] == 3),'Pclass'].count()
titanic_total_3rd = titanic.loc[(titanic['Pclass'] == 3), 'Pclass'].count()
print(f"La tasa de supervivencia de 1era fue {titanic_sob_1st* 100 / titanic_total_1st} %")
print(f"La tasa de supervivencia de 2da fue {titanic_sob_2nd* 100 / titanic_total_2nd} %")
print(f"La tasa de supervivencia de 3era fue {titanic_sob_3rd* 100 / titanic_total_3rd} %")
# Out:
# La tasa de supervivencia de 1era fue 67.0886075949367 %
# La tasa de supervivencia de 2da fue 80.0 %
# La tasa de supervivencia de 3era fue 50.0 %

# %% [markdown]
# Hacer graficos y sacar conclusiones, algunos ejemplos:
#
# - Relacion entre la clase en la que se viaja y la edad de la persona
# - Supervivencia por edad

# %%
import matplotlib.pyplot as plt
plt.bar(titanic['Pclass'], titanic['edad'])
# Out:
# <BarContainer object of 183 artists>

# %%
plt.bar(titanic['Survived'], titanic['edad'])
# Out:
# <BarContainer object of 183 artists>
